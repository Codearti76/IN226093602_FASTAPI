# %%
# %pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (7.2.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipykernel) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipykernel) (9.10.1)
# Requirement already satisfied: jupyter-client>=8.8.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipykernel) (26.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipykernel) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from jupyter-client>=8.8.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel) (4.9.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel) (0.8.6)
# Requirement already satisfied: wcwidth in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install -U langchain

from langchain_core.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate
# Out:
# Requirement already satisfied: langchain in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.2.28)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.29)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.12.1)
# Requirement already satisfied: certifi in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\vivek\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
template_1 = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

def explain_topic(topic):
    return template_1.format(topic=topic)

# Test
print(explain_topic("Artificial Intelligence"))
# Out:
# Explain Artificial Intelligence in simple terms for beginners

# %% [markdown]
# Multi-Input Prompt System

# %%
multi_input_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

# Test Cases
print(multi_input_template.format(topic="AI", audience="beginners", tone="friendly"))
print(multi_input_template.format(topic="Python", audience="kids", tone="fun"))
print(multi_input_template.format(topic="Deep Learning", audience="engineers", tone="technical"))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %% [markdown]
# Prompt Variations Engine

# %%
teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

topic = "Machine Learning"

print("Teaching:\n", teaching_template.format(topic=topic))
print("\nInterview:\n", interview_template.format(topic=topic))
print("\nStory:\n", story_template.format(topic=topic))
# Out:
# Teaching:
#  Explain Machine Learning clearly step by step
#
# Interview:
#  Ask 3 interview questions about Machine Learning
#
# Story:
#  Explain Machine Learning as a story

# %% [markdown]
# ChatPromptTemplate System

# %%
def get_chat_prompt(role, topic):

    if role == "teacher":
        system_message = "You are a helpful teacher who explains concepts clearly."
    elif role == "interviewer":
        system_message = "You are an interviewer asking insightful questions."
    elif role == "motivator":
        system_message = "You motivate and inspire learners."
    else:
        system_message = "You are a helpful assistant."

    chat_template = ChatPromptTemplate.from_messages([
        ("system", system_message),
        ("user", "Explain {topic}")
    ])

    return chat_template.format_messages(topic=topic)

# Test
messages = get_chat_prompt("teacher", "Neural Networks")
for msg in messages:
    print(msg)
# Out:
# content='You are a helpful teacher who explains concepts clearly.' additional_kwargs={} response_metadata={}
# content='Explain Neural Networks' additional_kwargs={} response_metadata={}

# %% [markdown]
# : Input Validation Layer

# %%
def validate_inputs(audience, tone):

    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]

    if audience not in valid_audience:
        print("Invalid audience! Setting default: beginner")
        audience = "beginner"

    if tone not in valid_tone:
        print("Invalid tone! Setting default: formal")
        tone = "formal"

    return audience, tone

# Test
print(validate_inputs("kids", "funny"))
# Out:
# Invalid audience! Setting default: beginner
# Invalid tone! Setting default: formal
# ('beginner', 'formal')

# %% [markdown]
# Prompt Generator App

# %%
def generate_prompt(topic, audience, tone, style):

    # Validate inputs
    audience, tone = validate_inputs(audience, tone)

    # Style templates
    styles = {
        "teaching": "Explain {topic} for {audience} in a {tone} teaching style",
        "interview": "Ask interview questions about {topic} for {audience} in a {tone} tone",
        "storytelling": "Explain {topic} for {audience} in a {tone} storytelling style"
    }

    template = PromptTemplate(
        input_variables=["topic", "audience", "tone"],
        template=styles.get(style)
    )

    return template.format(topic=topic, audience=audience, tone=tone)

# Test
print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))
# Out:
# Explain Neural Networks for beginner in a fun storytelling style

# %% [markdown]
# Template Reusability Test

# %%
reusable_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

inputs = [
    ("AI", "beginner", "fun"),
    ("Python", "intermediate", "formal"),
    ("ML", "expert", "casual"),
    ("Data Science", "beginner", "formal"),
    ("Deep Learning", "expert", "fun")
]

for topic, audience, tone in inputs:
    print(reusable_template.format(topic=topic, audience=audience, tone=tone))
# Out:
# Explain AI for beginner in a fun tone
# Explain Python for intermediate in a formal tone
# Explain ML for expert in a casual tone
# Explain Data Science for beginner in a formal tone
# Explain Deep Learning for expert in a fun tone

# %% [markdown]
# Final Pipeline Flow

# %%
def prompt_pipeline(topic, audience, tone, style):

    audience, tone = validate_inputs(audience, tone)

    prompt = generate_prompt(topic, audience, tone, style)

    return prompt

# Test
print(prompt_pipeline("Artificial Intelligence", "beginner", "fun", "teaching"))
# Out:
# Explain Artificial Intelligence for beginner in a fun teaching style
